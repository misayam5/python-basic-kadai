# %%
var = 15
if var % 3 == 0 and var % 5 == 0 :
    print("FizzBuzz")
elif var % 3 == 0:
    print("Fizz")
elif var % 5 == 0:
  print("Buzz")
else:
  print(var)
# Out:
# FizzBuzz

# %%
var = 7
if var % 3 == 0 and var % 5 == 0 :
    print("FizzBuzz")
elif var % 3 == 0:
    print("Fizz")
elif var % 5 == 0:
  print("Buzz")
else:
  print(var)
# Out:
# 7

# %%
var = 9
if var % 3 == 0 and var % 5 == 0 :
    print("FizzBuzz")
elif var % 3 == 0:
    print("Fizz")
elif var % 5 == 0:
  print("Buzz")
else:
  print(var)
# Out:
# Fizz

# %%
var = 10
if var % 3 == 0 and var % 5 == 0 :
    print("FizzBuzz")
elif var % 3 == 0:
    print("Fizz")
elif var % 5 == 0:
  print("Buzz")
else:
  print(var)
# Out:
# Buzz
